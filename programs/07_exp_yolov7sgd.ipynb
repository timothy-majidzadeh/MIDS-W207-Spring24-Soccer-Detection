# %%
from ultralytics import YOLO
import os

# Author: Timothy Majidzadeh
# Date Created: April 8, 2024
# Date Updated: April 12, 2024
# Date Updated: April 15, 2024 by Etienne Ndedi. Adjust directory path for analysis results of Yolov7 for training and testing
# Description: Compare the results of different batch sizes on YOLOv7.
# Notes: [v1] Created program.
# Inputs: Ultralytics-formatted data.
# Outputs: Model training & validation statistics for different versions of YOLO.

# %%
## 16
os.chdir("c:/Desktop/MIDS-W207/yolov7")
print("Batch size 16...")
# !python train.py --weights yolov7-tiny.pt --data data/soccertrack_square_oversampled.yaml --hyp data/hyp.scratch.custom.yaml --epochs 5 --batch-size 64 --img-size 800 --project ../MIDS-W207-Spring24-Soccer-Detection/analysis/sgd/train
print("Done!")

print("Validating YOLOv7...")
# !python test.py --weights ../MIDS-W207-Spring24-Soccer-Detection/analysis/sgd/train/exp/weights/best.pt --data data/soccertrack_square_oversampled.yaml --batch-size 64 --img-size 800 --iou-thres 0.5 --verbose --save-txt --save-conf --project ../MIDS-W207-Spring24-Soccer-Detection/analysis/sgd/val --task val
print("Done!")
# Out:
# Batch size 16...
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)Done!
# Validating YOLOv7...
#
# Downloading https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-tiny.pt to yolov7-tiny.pt...
#
#
# autoanchor: Analyzing anchors... anchors/target = 5.06, Best Possible Recall (BPR) = 0.9907
#                  all        1040        6894        0.53       0.373       0.206      0.0537
#                  all        1040        6894       0.633       0.388       0.383        0.11
#                  all        1040        6894       0.693       0.669       0.627       0.218
#                  all        1040        6894       0.795       0.692       0.689       0.248
#                  all        1040        6894       0.808       0.714       0.717       0.273
#                 ball        1040         511       0.701       0.399       0.378        0.12
#               team_0        1040        3163       0.862       0.864       0.885       0.352
#               team_1        1040        3220       0.861        0.88       0.888       0.345
# Optimizer stripped from ..\MIDS-W207-Spring24-Soccer-Detection\analysis\sgd\train\exp\weights\last.pt, 12.3MB
# Optimizer stripped from ..\MIDS-W207-Spring24-Soccer-Detection\analysis\sgd\train\exp\weights\best.pt, 12.3MB
# YOLOR  v0.1-128-ga207844 torch 2.2.2+cpu CPU
#
# Namespace(weights='yolov7-tiny.pt', cfg='', data='data/soccertrack_square_oversampled.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=5, batch_size=64, img_size=[800, 800], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='../MIDS-W207-Spring24-Soccer-Detection/analysis/sgd/train', entity=None, name='exp', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='..\\MIDS-W207-Spring24-Soccer-Detection\\analysis\\sgd\\train\\exp', total_batch_size=64)
# tensorboard: Start with 'tensorboard --logdir ../MIDS-W207-Spring24-Soccer-Detection/analysis/sgd/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, paste_in=0.0, loss_ota=0
#
#   0%|          | 0.00/12.1M [00:00<?, ?B/s]
#   6%|5         | 680k/12.1M [00:00<00:01, 6.96MB/s]
#  29%|##9       | 3.53M/12.1M [00:00<00:00, 20.3MB/s]
#  79%|#######8  | 9.48M/12.1M [00:00<00:00, 39.3MB/s]
# 100%|##########| 12.1M/12.1M [00:00<00:00, 36.3MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#   2                -1  1      2112  models.common.Conv                      [64, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   3                -2  1      2112  models.common.Conv                      [64, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   4                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   5                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   6  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#   7                -1  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   8                -1  1         0  models.common.MP                        []
#   9                -1  1      4224  models.common.Conv                      [64, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  10                -2  1      4224  models.common.Conv                      [64, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  11                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  12                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  13  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  15                -1  1         0  models.common.MP                        []
#  16                -1  1     16640  models.common.Conv                      [128, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  17                -2  1     16640  models.common.Conv                      [128, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  20  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  21                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  22                -1  1         0  models.common.MP                        []
#  23                -1  1     66048  models.common.Conv                      [256, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  24                -2  1     66048  models.common.Conv                      [256, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  25                -1  1    590336  models.common.Conv                      [256, 256, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  26                -1  1    590336  models.common.Conv                      [256, 256, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  27  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  28                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  29                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  30                -2  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  31                -1  1         0  models.common.SP                        [5]
#  32                -2  1         0  models.common.SP                        [9]
#  33                -3  1         0  models.common.SP                        [13]
#  34  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  35                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  36          [-1, -7]  1         0  models.common.Concat                    [1]
#  37                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  38                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  39                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  40                21  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  41          [-1, -2]  1         0  models.common.Concat                    [1]
#  42                -1  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  43                -2  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  44                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  45                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  46  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  47                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  48                -1  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  49                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  50                14  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  51          [-1, -2]  1         0  models.common.Concat                    [1]
#  52                -1  1      4160  models.common.Conv                      [128, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  53                -2  1      4160  models.common.Conv                      [128, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  54                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  55                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  56  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  57                -1  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  58                -1  1     73984  models.common.Conv                      [64, 128, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#  59          [-1, 47]  1         0  models.common.Concat                    [1]
#  60                -1  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  61                -2  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  62                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  63                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  64  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  65                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  66                -1  1    295424  models.common.Conv                      [128, 256, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#  67          [-1, 37]  1         0  models.common.Concat                    [1]
#  68                -1  1     65792  models.common.Conv                      [512, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  69                -2  1     65792  models.common.Conv                      [512, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  70                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  71                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  72  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  73                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  74                57  1     73984  models.common.Conv                      [64, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  75                65  1    295424  models.common.Conv                      [128, 256, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  76                73  1   1180672  models.common.Conv                      [256, 512, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  77      [74, 75, 76]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# C:\Users\patnd\anaconda3\Lib\site-packages\torch\functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 255 layers, 6019432 parameters, 6019432 gradients, 13.2 GFLOPS
#
# Transferred 332/338 items from yolov7-tiny.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 58 .bias, 58 conv.weight, 55 other
#
# Scanning images:   0%|          | 0/8320 [00:00<?, ?it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 8 found, 0 missing, 2 empty, 0 corrupted:   0%|          | 8/8320 [00:00<01:44, 79.19it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 16 found, 0 missing, 8 empty, 0 corrupted:   0%|          | 16/8320 [00:00<01:49, 75.55it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 24 found, 0 missing, 10 empty, 0 corrupted:   0%|          | 24/8320 [00:00<02:04, 66.47it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 31 found, 0 missing, 12 empty, 0 corrupted:   0%|          | 31/8320 [00:00<02:10, 63.36it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 38 found, 0 missing, 12 empty, 0 corrupted:   0%|          | 38/8320 [00:00<02:25, 57.07it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 44 found, 0 missing, 13 empty, 0 corrupted:   1%|          | 44/8320 [00:00<02:23, 57.84it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 50 found, 0 missing, 13 empty, 0 corrupted:   1%|          | 50/8320 [00:00<02:26, 56.31it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 56 found, 0 missing, 13 empty, 0 corrupted:   1%|          | 56/8320 [00:00<02:29, 55.45it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 62 found, 0 missing, 14 empty, 0 corrupted:   1%|          | 62/8320 [00:01<02:35, 52.95it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 69 found, 0 missing, 15 empty, 0 corrupted:   1%|          | 69/8320 [00:01<02:23, 57.59it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 75 found, 0 missing, 18 empty, 0 corrupted:   1%|          | 75/8320 [00:01<02:32, 53.97it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 82 found, 0 missing, 21 empty, 0 corrupted:   1%|          | 82/8320 [00:01<02:26, 56.21it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 88 found, 0 missing, 22 empty, 0 corrupted:   1%|1         | 88/8320 [00:01<02:29, 55.02it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 94 found, 0 missing, 23 empty, 0 corrupted:   1%|1         | 94/8320 [00:01<02:30, 54.53it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 100 found, 0 missing, 24 empty, 0 corrupted:   1%|1         | 100/8320 [00:01<02:39, 51.65it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 106 found, 0 missing, 25 empty, 0 corrupted:   1%|1         | 106/8320 [00:01<02:35, 52.75it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 112 found, 0 missing, 26 empty, 0 corrupted:   1%|1         | 112/8320 [00:01<02:37, 52.08it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 118 found, 0 missing, 27 empty, 0 corrupted:   1%|1         | 118/8320 [00:02<02:35, 52.61it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 124 found, 0 missing, 28 empty, 0 corrupted:   1%|1         | 124/8320 [00:02<02:34, 53.02it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 130 found, 0 missing, 28 empty, 0 corrupted:   2%|1         | 130/8320 [00:02<02:31, 54.06it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 136 found, 0 missing, 29 empty, 0 corrupted:   2%|1         | 136/8320 [00:02<02:32, 53.82it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 143 found, 0 missing, 32 empty, 0 corrupted:   2%|1         | 143/8320 [00:02<02:24, 56.72it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 150 found, 0 missing, 35 empty, 0 corrupted:   2%|1         | 150/8320 [00:02<02:20, 58.14it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 157 found, 0 missing, 36 empty, 0 corrupted:   2%|1         | 157/8320 [00:02<02:14, 60.52it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 164 found, 0 missing, 36 empty, 0 corrupted:   2%|1         | 164/8320 [00:02<02:15, 60.08it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 171 found, 0 missing, 38 empty, 0 corrupted:   2%|2         | 171/8320 [00:03<02:23, 56.74it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 177 found, 0 missing, 39 empty, 0 corrupted:   2%|2         | 177/8320 [00:03<02:23, 56.87it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 184 found, 0 missing, 39 empty, 0 corrupted:   2%|2         | 184/8320 [00:03<02:15, 59.84it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 191 found, 0 missing, 40 empty, 0 corrupted:   2%|2         | 191/8320 [00:03<02:13, 60.84it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 198 found, 0 missing, 41 empty, 0 corrupted:   2%|2         | 198/8320 [00:03<02:19, 58.18it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 204 found, 0 missing, 42 empty, 0 corrupted:   2%|2         | 204/8320 [00:03<02:25, 55.85it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 211 found, 0 missing, 43 empty, 0 corrupted:   3%|2         | 211/8320 [00:03<02:19, 58.24it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 218 found, 0 missing, 44 empty, 0 corrupted:   3%|2         | 218/8320 [00:03<02:15, 59.69it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 225 found, 0 missing, 47 empty, 0 corrupted:   3%|2         | 225/8320 [00:03<02:15, 59.59it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 231 found, 0 missing, 47 empty, 0 corrupted:   3%|2         | 231/8320 [00:04<02:20, 57.70it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 238 found, 0 missing, 49 empty, 0 corrupted:   3%|2         | 238/8320 [00:04<02:15, 59.48it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 245 found, 0 missing, 51 empty, 0 corrupted:   3%|2         | 245/8320 [00:04<02:11, 61.46it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 252 found, 0 missing, 53 empty, 0 corrupted:   3%|3         | 252/8320 [00:04<02:12, 60.88it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 259 found, 0 missing, 54 empty, 0 corrupted:   3%|3         | 259/8320 [00:04<02:17, 58.47it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 265 found, 0 missing, 56 empty, 0 corrupted:   3%|3         | 265/8320 [00:04<02:16, 58.84it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 272 found, 0 missing, 57 empty, 0 corrupted:   3%|3         | 272/8320 [00:04<02:14, 59.83it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 279 found, 0 missing, 59 empty, 0 corrupted:   3%|3         | 279/8320 [00:04<02:11, 61.02it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 286 found, 0 missing, 59 empty, 0 corrupted:   3%|3         | 286/8320 [00:04<02:10, 61.62it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 293 found, 0 missing, 61 empty, 0 corrupted:   4%|3         | 293/8320 [00:05<02:10, 61.31it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 300 found, 0 missing, 61 empty, 0 corrupted:   4%|3         | 300/8320 [00:05<02:14, 59.59it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 307 found, 0 missing, 62 empty, 0 corrupted:   4%|3         | 307/8320 [00:05<02:14, 59.71it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 313 found, 0 missing, 62 empty, 0 corrupted:   4%|3         | 313/8320 [00:05<02:20, 57.03it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 319 found, 0 missing, 62 empty, 0 corrupted:   4%|3         | 319/8320 [00:05<02:32, 52.45it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 326 found, 0 missing, 63 empty, 0 corrupted:   4%|3         | 326/8320 [00:05<02:25, 54.88it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 332 found, 0 missing, 63 empty, 0 corrupted:   4%|3         | 332/8320 [00:05<02:29, 53.30it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 338 found, 0 missing, 64 empty, 0 corrupted:   4%|4         | 338/8320 [00:05<02:29, 53.51it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 344 found, 0 missing, 65 empty, 0 corrupted:   4%|4         | 344/8320 [00:06<02:31, 52.73it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 350 found, 0 missing, 66 empty, 0 corrupted:   4%|4         | 350/8320 [00:06<02:35, 51.28it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 356 found, 0 missing, 68 empty, 0 corrupted:   4%|4         | 356/8320 [00:06<02:31, 52.56it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 362 found, 0 missing, 69 empty, 0 corrupted:   4%|4         | 362/8320 [00:06<02:27, 54.05it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 368 found, 0 missing, 69 empty, 0 corrupted:   4%|4         | 368/8320 [00:06<02:37, 50.60it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 374 found, 0 missing, 72 empty, 0 corrupted:   4%|4         | 374/8320 [00:06<02:43, 48.57it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 380 found, 0 missing, 73 empty, 0 corrupted:   5%|4         | 380/8320 [00:06<02:40, 49.41it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 386 found, 0 missing, 74 empty, 0 corrupted:   5%|4         | 386/8320 [00:06<02:33, 51.52it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 392 found, 0 missing, 76 empty, 0 corrupted:   5%|4         | 392/8320 [00:07<02:58, 44.31it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 398 found, 0 missing, 78 empty, 0 corrupted:   5%|4         | 398/8320 [00:07<02:49, 46.62it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 404 found, 0 missing, 79 empty, 0 corrupted:   5%|4         | 404/8320 [00:07<02:48, 47.08it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 409 found, 0 missing, 79 empty, 0 corrupted:   5%|4         | 409/8320 [00:07<02:49, 46.65it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 414 found, 0 missing, 83 empty, 0 corrupted:   5%|4         | 414/8320 [00:07<03:11, 41.33it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 419 found, 0 missing, 84 empty, 0 corrupted:   5%|5         | 419/8320 [00:07<03:24, 38.65it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 423 found, 0 missing, 85 empty, 0 corrupted:   5%|5         | 423/8320 [00:07<03:34, 36.82it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 428 found, 0 missing, 87 empty, 0 corrupted:   5%|5         | 428/8320 [00:07<03:21, 39.13it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 435 found, 0 missing, 88 empty, 0 corrupted:   5%|5         | 435/8320 [00:08<02:48, 46.68it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 442 found, 0 missing, 91 empty, 0 corrupted:   5%|5         | 442/8320 [00:08<02:33, 51.31it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 448 found, 0 missing, 92 empty, 0 corrupted:   5%|5         | 448/8320 [00:08<02:35, 50.61it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 454 found, 0 missing, 93 empty, 0 corrupted:   5%|5         | 454/8320 [00:08<02:30, 52.37it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 460 found, 0 missing, 94 empty, 0 corrupted:   6%|5         | 460/8320 [00:08<02:25, 54.01it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 466 found, 0 missing, 95 empty, 0 corrupted:   6%|5         | 466/8320 [00:08<02:28, 52.83it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 473 found, 0 missing, 97 empty, 0 corrupted:   6%|5         | 473/8320 [00:08<02:22, 55.20it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 483 found, 0 missing, 100 empty, 0 corrupted:   6%|5         | 483/8320 [00:08<01:57, 66.45it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 492 found, 0 missing, 102 empty, 0 corrupted:   6%|5         | 492/8320 [00:08<01:51, 70.31it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 500 found, 0 missing, 103 empty, 0 corrupted:   6%|6         | 500/8320 [00:09<01:55, 67.54it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 507 found, 0 missing, 104 empty, 0 corrupted:   6%|6         | 507/8320 [00:09<01:54, 68.14it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 514 found, 0 missing, 104 empty, 0 corrupted:   6%|6         | 514/8320 [00:09<01:58, 66.05it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 521 found, 0 missing, 104 empty, 0 corrupted:   6%|6         | 521/8320 [00:09<02:03, 63.29it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 528 found, 0 missing, 104 empty, 0 corrupted:   6%|6         | 528/8320 [00:09<02:01, 63.90it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 535 found, 0 missing, 104 empty, 0 corrupted:   6%|6         | 535/8320 [00:09<02:00, 64.72it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 542 found, 0 missing, 105 empty, 0 corrupted:   7%|6         | 542/8320 [00:09<02:02, 63.33it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 549 found, 0 missing, 108 empty, 0 corrupted:   7%|6         | 549/8320 [00:09<02:12, 58.66it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 555 found, 0 missing, 109 empty, 0 corrupted:   7%|6         | 555/8320 [00:09<02:15, 57.39it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 562 found, 0 missing, 111 empty, 0 corrupted:   7%|6         | 562/8320 [00:10<02:10, 59.34it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 569 found, 0 missing, 112 empty, 0 corrupted:   7%|6         | 569/8320 [00:10<02:08, 60.50it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 576 found, 0 missing, 113 empty, 0 corrupted:   7%|6         | 576/8320 [00:10<02:07, 60.54it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 583 found, 0 missing, 116 empty, 0 corrupted:   7%|7         | 583/8320 [00:10<02:05, 61.84it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 590 found, 0 missing, 117 empty, 0 corrupted:   7%|7         | 590/8320 [00:10<02:05, 61.38it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 597 found, 0 missing, 119 empty, 0 corrupted:   7%|7         | 597/8320 [00:10<02:02, 63.23it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 604 found, 0 missing, 120 empty, 0 corrupted:   7%|7         | 604/8320 [00:10<02:01, 63.56it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 612 found, 0 missing, 121 empty, 0 corrupted:   7%|7         | 612/8320 [00:10<01:55, 66.91it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 619 found, 0 missing, 121 empty, 0 corrupted:   7%|7         | 619/8320 [00:10<02:03, 62.59it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 626 found, 0 missing, 122 empty, 0 corrupted:   8%|7         | 626/8320 [00:11<02:04, 61.56it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 633 found, 0 missing, 122 empty, 0 corrupted:   8%|7         | 633/8320 [00:11<02:07, 60.35it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 640 found, 0 missing, 123 empty, 0 corrupted:   8%|7         | 640/8320 [00:11<02:10, 58.66it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 651 found, 0 missing, 127 empty, 0 corrupted:   8%|7         | 651/8320 [00:11<01:47, 71.58it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 659 found, 0 missing, 129 empty, 0 corrupted:   8%|7         | 659/8320 [00:11<01:49, 69.84it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 667 found, 0 missing, 129 empty, 0 corrupted:   8%|8         | 667/8320 [00:11<01:51, 68.77it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 674 found, 0 missing, 131 empty, 0 corrupted:   8%|8         | 674/8320 [00:11<01:52, 68.17it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 681 found, 0 missing, 133 empty, 0 corrupted:   8%|8         | 681/8320 [00:11<01:52, 67.87it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 688 found, 0 missing, 133 empty, 0 corrupted:   8%|8         | 688/8320 [00:12<01:58, 64.25it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 695 found, 0 missing, 134 empty, 0 corrupted:   8%|8         | 695/8320 [00:12<01:56, 65.57it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 702 found, 0 missing, 134 empty, 0 corrupted:   8%|8         | 702/8320 [00:12<02:03, 61.85it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 709 found, 0 missing, 135 empty, 0 corrupted:   9%|8         | 709/8320 [00:12<02:00, 63.11it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 716 found, 0 missing, 136 empty, 0 corrupted:   9%|8         | 716/8320 [00:12<02:03, 61.54it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 723 found, 0 missing, 137 empty, 0 corrupted:   9%|8         | 723/8320 [00:12<02:09, 58.86it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 729 found, 0 missing, 138 empty, 0 corrupted:   9%|8         | 729/8320 [00:12<02:16, 55.74it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 735 found, 0 missing, 139 empty, 0 corrupted:   9%|8         | 735/8320 [00:12<02:17, 55.01it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 741 found, 0 missing, 140 empty, 0 corrupted:   9%|8         | 741/8320 [00:12<02:18, 54.85it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 747 found, 0 missing, 140 empty, 0 corrupted:   9%|8         | 747/8320 [00:13<02:20, 53.76it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 753 found, 0 missing, 143 empty, 0 corrupted:   9%|9         | 753/8320 [00:13<02:23, 52.77it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 759 found, 0 missing, 143 empty, 0 corrupted:   9%|9         | 759/8320 [00:13<02:24, 52.48it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 765 found, 0 missing, 144 empty, 0 corrupted:   9%|9         | 765/8320 [00:13<02:19, 54.05it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 771 found, 0 missing, 145 empty, 0 corrupted:   9%|9         | 771/8320 [00:13<02:17, 54.84it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 777 found, 0 missing, 145 empty, 0 corrupted:   9%|9         | 777/8320 [00:13<02:16, 55.46it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 783 found, 0 missing, 148 empty, 0 corrupted:   9%|9         | 783/8320 [00:13<02:14, 55.99it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 790 found, 0 missing, 150 empty, 0 corrupted:   9%|9         | 790/8320 [00:13<02:07, 58.98it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 797 found, 0 missing, 151 empty, 0 corrupted:  10%|9         | 797/8320 [00:13<02:01, 61.71it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 807 found, 0 missing, 152 empty, 0 corrupted:  10%|9         | 807/8320 [00:14<01:46, 70.51it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 815 found, 0 missing, 154 empty, 0 corrupted:  10%|9         | 815/8320 [00:14<01:56, 64.49it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 823 found, 0 missing, 154 empty, 0 corrupted:  10%|9         | 823/8320 [00:14<01:52, 66.83it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 830 found, 0 missing, 154 empty, 0 corrupted:  10%|9         | 830/8320 [00:14<01:59, 62.88it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 837 found, 0 missing, 156 empty, 0 corrupted:  10%|#         | 837/8320 [00:14<01:55, 64.53it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 844 found, 0 missing, 158 empty, 0 corrupted:  10%|#         | 844/8320 [00:14<01:58, 63.09it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 851 found, 0 missing, 160 empty, 0 corrupted:  10%|#         | 851/8320 [00:14<02:05, 59.39it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 858 found, 0 missing, 160 empty, 0 corrupted:  10%|#         | 858/8320 [00:14<02:12, 56.15it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 864 found, 0 missing, 162 empty, 0 corrupted:  10%|#         | 864/8320 [00:15<02:17, 54.26it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 870 found, 0 missing, 165 empty, 0 corrupted:  10%|#         | 870/8320 [00:15<02:14, 55.26it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 876 found, 0 missing, 168 empty, 0 corrupted:  11%|#         | 876/8320 [00:15<02:16, 54.45it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 882 found, 0 missing, 169 empty, 0 corrupted:  11%|#         | 882/8320 [00:15<02:17, 54.22it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 888 found, 0 missing, 170 empty, 0 corrupted:  11%|#         | 888/8320 [00:15<02:21, 52.52it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 894 found, 0 missing, 172 empty, 0 corrupted:  11%|#         | 894/8320 [00:15<02:21, 52.61it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 900 found, 0 missing, 172 empty, 0 corrupted:  11%|#         | 900/8320 [00:15<02:16, 54.22it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 906 found, 0 missing, 172 empty, 0 corrupted:  11%|#         | 906/8320 [00:15<02:19, 53.17it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 913 found, 0 missing, 172 empty, 0 corrupted:  11%|#         | 913/8320 [00:15<02:08, 57.50it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 920 found, 0 missing, 173 empty, 0 corrupted:  11%|#1        | 920/8320 [00:16<02:02, 60.36it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 928 found, 0 missing, 175 empty, 0 corrupted:  11%|#1        | 928/8320 [00:16<01:53, 64.96it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 935 found, 0 missing, 176 empty, 0 corrupted:  11%|#1        | 935/8320 [00:16<01:52, 65.70it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 942 found, 0 missing, 176 empty, 0 corrupted:  11%|#1        | 942/8320 [00:16<01:53, 64.87it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 949 found, 0 missing, 177 empty, 0 corrupted:  11%|#1        | 949/8320 [00:16<01:54, 64.33it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 957 found, 0 missing, 178 empty, 0 corrupted:  12%|#1        | 957/8320 [00:16<01:51, 66.14it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 965 found, 0 missing, 179 empty, 0 corrupted:  12%|#1        | 965/8320 [00:16<01:48, 68.08it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 972 found, 0 missing, 180 empty, 0 corrupted:  12%|#1        | 972/8320 [00:16<01:53, 65.01it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 981 found, 0 missing, 182 empty, 0 corrupted:  12%|#1        | 981/8320 [00:16<01:43, 70.68it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 989 found, 0 missing, 183 empty, 0 corrupted:  12%|#1        | 989/8320 [00:17<01:48, 67.45it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 996 found, 0 missing, 186 empty, 0 corrupted:  12%|#1        | 996/8320 [00:17<01:49, 66.89it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1003 found, 0 missing, 188 empty, 0 corrupted:  12%|#2        | 1003/8320 [00:17<01:51, 65.45it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1010 found, 0 missing, 188 empty, 0 corrupted:  12%|#2        | 1010/8320 [00:17<01:54, 63.93it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1017 found, 0 missing, 189 empty, 0 corrupted:  12%|#2        | 1017/8320 [00:17<02:03, 59.29it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1024 found, 0 missing, 189 empty, 0 corrupted:  12%|#2        | 1024/8320 [00:17<02:00, 60.38it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1031 found, 0 missing, 192 empty, 0 corrupted:  12%|#2        | 1031/8320 [00:17<02:00, 60.59it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1038 found, 0 missing, 194 empty, 0 corrupted:  12%|#2        | 1038/8320 [00:17<01:55, 62.84it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1045 found, 0 missing, 198 empty, 0 corrupted:  13%|#2        | 1045/8320 [00:17<01:53, 63.86it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1052 found, 0 missing, 198 empty, 0 corrupted:  13%|#2        | 1052/8320 [00:18<01:57, 61.91it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1059 found, 0 missing, 200 empty, 0 corrupted:  13%|#2        | 1059/8320 [00:18<02:05, 57.75it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1065 found, 0 missing, 200 empty, 0 corrupted:  13%|#2        | 1065/8320 [00:18<02:04, 58.27it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1072 found, 0 missing, 202 empty, 0 corrupted:  13%|#2        | 1072/8320 [00:18<01:59, 60.77it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1079 found, 0 missing, 204 empty, 0 corrupted:  13%|#2        | 1079/8320 [00:18<02:03, 58.42it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_train_v1' images and labels... 1086 found, 0 missing, 204 empty, 0 corrupted:  13%|#3        | 1086/8320 [00:18<02:01, 59.48it/s]
# train: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled
[00:00<?, ?it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  11%|#1        | 1/9 [01:03<08:24, 63.03s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  22%|##2       | 2/9 [02:04<07:13, 61.97s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  33%|###3      | 3/9 [03:03<06:04, 60.79s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  44%|####4     | 4/9 [04:06<05:07, 61.59s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  56%|#####5    | 5/9 [05:08<04:07, 61.87s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  67%|######6   | 6/9 [06:11<03:06, 62.25s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  78%|#######7  | 7/9 [07:13<02:04, 62.11s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  89%|########8 | 8/9 [08:17<01:02, 62.81s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 9/9 [08:26<00:00, 45.76s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 9/9 [08:26<00:00, 56.25s/it]
# 5 epochs completed in 24.526 hours.
# Namespace(weights=['../MIDS-W207-Spring24-Soccer-Detection/analysis/sgd/train/exp/weights/best.pt'], data='data/soccertrack_square_oversampled.yaml', batch_size=64, img_size=800, conf_thres=0.001, iou_thres=0.5, task='val', device='', single_cls=False, augment=False, verbose=True, save_txt=True, save_hybrid=False, save_conf=True, save_json=False, project='../MIDS-W207-Spring24-Soccer-Detection/analysis/sgd/val', name='exp', exist_ok=False, no_trace=False, v5_metric=False)
# Fusing layers...
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#                  all        1040        6894       0.834       0.715       0.723       0.274
#                 ball        1040         511       0.733       0.403       0.398       0.126
#               team_0        1040        3163       0.888       0.864       0.885       0.352
#               team_1        1040        3220       0.881       0.878       0.886       0.345
# Speed: 412.4/3.9/416.3 ms inference/NMS/total per 800x800 image at batch-size 64
# Results saved to ..\MIDS-W207-Spring24-Soccer-Detection\analysis\sgd\val\exp
# 1010 labels saved to ..\MIDS-W207-Spring24-Soccer-Detection\analysis\sgd\val\exp\labels
# Done!
# YOLOR  v0.1-128-ga207844 torch 2.2.2+cpu CPU
#
# C:\Users\patnd\anaconda3\Lib\site-packages\torch\functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 200 layers, 6012040 parameters, 0 gradients, 13.0 GFLOPS
#
# val: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_val_v1.cache' images and labels... 1040 found, 0 missing, 213 empty, 0 corrupted: 100%|##########| 1040/1040 [00:00<?, ?it/s]
# val: Scanning 'c:\Desktop\MIDS-W207\datasets\soccertrack_square\splits\oversampled_val_v1.cache' images and labels... 1040 found, 0 missing, 213 empty, 0 corrupted: 100%|##########| 1040/1040 [00:00<?, ?it/s]
#
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   0%|          | 0/17 [00:00<?, ?it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   6%|5         | 1/17 [00:42<11:13, 42.07s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  12%|#1        | 2/17 [01:17<09:29, 37.99s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  18%|#7        | 3/17 [01:55<08:54, 38.16s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  24%|##3       | 4/17 [02:32<08:09, 37.66s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  29%|##9       | 5/17 [03:08<07:26, 37.22s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  35%|###5      | 6/17 [03:43<06:40, 36.37s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  41%|####1     | 7/17 [04:19<06:01, 36.14s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  47%|####7     | 8/17 [04:56<05:27, 36.39s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  53%|#####2    | 9/17 [05:32<04:50, 36.28s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  59%|#####8    | 10/17 [06:07<04:12, 36.03s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  65%|######4   | 11/17 [06:43<03:35, 35.84s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  71%|#######   | 12/17 [07:16<02:54, 34.98s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  76%|#######6  | 13/17 [07:51<02:20, 35.17s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  82%|########2 | 14/17 [08:27<01:45, 35.19s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  88%|########8 | 15/17 [09:02<01:10, 35.22s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  94%|#########4| 16/17 [09:37<00:35, 35.19s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 17/17 [09:46<00:00, 27.33s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 17/17 [09:46<00:00, 34.50s/it]
