# %%
import os
os.chdir("D:/MIDS-W207/yolov5")

# %%
os.getcwd()
# Out:
# 'D:\\MIDS-W207\\yolov5'

# %%
# !python train.py --weights yolov5n.pt --data data/soccertrack.yaml --epochs 3 --batch-size 32 --imgsz 800 --rect \
--optimizer Adam --project ../MIDS-W207-Spring24-Soccer-Detection/analysis/YOLOv5/train
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# train: weights=yolov5n.pt, cfg=, data=data/soccertrack.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=3, batch_size=32, imgsz=800, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=../MIDS-W207-Spring24-Soccer-Detection/analysis/YOLOv5/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# YOLOv5  2024-3-12 Python-3.9.18 torch-2.2.1+cpu CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir ..\MIDS-W207-Spring24-Soccer-Detection\analysis\YOLOv5\train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1     10824  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model summary: 214 layers, 1767976 parameters, 1767976 gradients, 4.2 GFLOPs
#
# Transferred 343/349 items from yolov5n.pt
# optimizer: Adam(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# WARNING  --rect is incompatible with DataLoader shuffle, setting shuffle=False
#
# train: Scanning D:\MIDS-W207\datasets\soccertrack\train_v1...:   0%|          | 0/70 [00:00<?, ?it/s]
# train: Scanning D:\MIDS-W207\datasets\soccertrack\train_v1... 1 images, 0 backgrounds, 0 corrupt:   1%|1         | 1/70 [00:08<09:30,  8.27s/it]
# train: Scanning D:\MIDS-W207\datasets\soccertrack\train_v1... 26 images, 0 backgrounds, 0 corrupt:  37%|###7      | 26/70 [00:08<00:10,  4.36it/s]
# train: Scanning D:\MIDS-W207\datasets\soccertrack\train_v1... 62 images, 0 backgrounds, 1 corrupt:  90%|######### | 63/70 [00:08<00:00, 13.01it/s]
# train: Scanning D:\MIDS-W207\datasets\soccertrack\train_v1... 69 images, 0 backgrounds, 1 corrupt: 100%|##########| 70/70 [00:08<00:00,  8.24it/s]
# train: WARNING  D:\MIDS-W207\datasets\soccertrack\images\top_view\D_20220220_1_0000_0030\D_20220220_1_0000_0030_62.png: ignoring corrupt image/label: [Errno 2] No such file or directory: 'D:\\MIDS-W207\\datasets\\soccertrack\\images\\top_view\\D_20220220_1_0000_0030\\D_20220220_1_0000_0030_62.png'
# train: WARNING  Cache directory D:\MIDS-W207\datasets\soccertrack is not writeable: [WinError 183] Cannot create a file when that file already exists: 'D:\\MIDS-W207\\datasets\\soccertrack\\train_v1.cache.npy' -> 'D:\\MIDS-W207\\datasets\\soccertrack\\train_v1.cache'
#
# val: Scanning D:\MIDS-W207\datasets\soccertrack\val_v1...:   0%|          | 0/15 [00:00<?, ?it/s]
# val: Scanning D:\MIDS-W207\datasets\soccertrack\val_v1... 1 images, 0 backgrounds, 0 corrupt:   7%|6         | 1/15 [00:11<02:36, 11.17s/it]
# val: Scanning D:\MIDS-W207\datasets\soccertrack\val_v1... 13 images, 0 backgrounds, 0 corrupt:  87%|########6 | 13/15 [00:11<00:01,  1.60it/s]
# val: Scanning D:\MIDS-W207\datasets\soccertrack\val_v1... 15 images, 0 backgrounds, 0 corrupt: 100%|##########| 15/15 [00:11<00:00,  1.33it/s]
# val: WARNING  Cache directory D:\MIDS-W207\datasets\soccertrack is not writeable: [WinError 183] Cannot create a file when that file already exists: 'D:\\MIDS-W207\\datasets\\soccertrack\\val_v1.cache.npy' -> 'D:\\MIDS-W207\\datasets\\soccertrack\\val_v1.cache'
#
# AutoAnchor: 2.09 anchors/target, 0.957 Best Possible Recall (BPR). Anchors are a poor fit to dataset , attempting to improve...
# AutoAnchor: WARNING  Extremely small objects found: 69 of 1587 labels are <3 pixels in size
# AutoAnchor: Running kmeans for 9 anchors on
# 100%|##########| 1000/1000 [00:08<00:00, 111.90it/s]
# AutoAnchor: thr=0.25: 0.0000 best possible recall, 0.00 anchors past thr
# AutoAnchor: n=9, img_size=800, metric_all=0.038/0.160-mean/best, past_thr=nan-mean: 33,48, 62,104, 216,283, 380,415, 436,454, 487,488, 540,582, 614,639, 693,772
# AutoAnchor: Done  (original anchors better than new anchors, proceeding with original anchors)
# Plotting labels to ..\MIDS-W207-Spring24-Soccer-Detection\analysis\YOLOv5\train\exp\labels.jpg...
# Image sizes 800 train, 800 val
# Using 8 dataloader workers
# Logging results to ..\MIDS-W207-Spring24-Soccer-Detection\analysis\YOLOv5\train\exp
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#         0/2         0G    0.05102    0.04497    0.01363        712        800:   0%|          | 0/3 [00:07<?, ?it/s]
#         0/2         0G    0.05102    0.04497    0.01363        712        800:  33%|###3      | 1/3 [00:07<00:14,  7.18s/it]
#         0/2         0G     0.0501    0.04237    0.01268        704        800:  33%|###3      | 1/3 [00:13<00:14,  7.18s/it]
#         0/2         0G     0.0501    0.04237    0.01268        704        800:  67%|######6   | 2/3 [00:13<00:06,  6.96s/it]
#         0/2         0G    0.04979    0.03845    0.01172        111        800:  67%|######6   | 2/3 [00:15<00:06,  6.96s/it]
#         0/2         0G    0.04979    0.03845    0.01172        111        800: 100%|##########| 3/3 [00:15<00:00,  4.30s/it]
#         0/2         0G    0.04979    0.03845    0.01172        111        800: 100%|##########| 3/3 [00:15<00:00,  5.04s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 1.250s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:02<00:00,  2.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:02<00:00,  2.19s/it]
#                    all         15        345          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#         1/2         0G    0.04766    0.03447   0.009283        710        800:   0%|          | 0/3 [-1:58:03<?, ?it/s]
#         1/2         0G    0.04775    0.03105    0.00894        709        800:   0%|          | 0/3 [-1:58:09<?, ?it/s]
#         1/2         0G     0.0484    0.02484   0.008643        110        800:   0%|          | 0/3 [-1:58:10<?, ?it/s]
#         1/2         0G     0.0484    0.02484   0.008643        110        800: 100%|##########| 3/3 [-1:58:10<00:00, -0.03it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:01<00:00,  1.69s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:01<00:00,  1.69s/it]
#                    all         15        345          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#         2/2         0G    0.04689    0.02624   0.007603        709        800:   0%|          | 0/3 [00:06<?, ?it/s]
#         2/2         0G    0.04689    0.02624   0.007603        709        800:  33%|###3      | 1/3 [00:06<00:13,  6.95s/it]
#         2/2         0G     0.0465    0.02802   0.007554        707        800:  33%|###3      | 1/3 [00:13<00:13,  6.95s/it]
#         2/2         0G     0.0465    0.02802   0.007554        707        800:  67%|######6   | 2/3 [00:13<00:06,  6.86s/it]
#         2/2         0G    0.04636    0.02676    0.00759        109        800:  67%|######6   | 2/3 [00:14<00:06,  6.86s/it]
#         2/2         0G    0.04636    0.02676    0.00759        109        800: 100%|##########| 3/3 [00:14<00:00,  4.19s/it]
#         2/2         0G    0.04636    0.02676    0.00759        109        800: 100%|##########| 3/3 [00:14<00:00,  4.92s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:01<00:00,  1.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:01<00:00,  1.19s/it]
#                    all         15        345          0          0          0          0
#
# 3 epochs completed in -0.021 hours.
# Optimizer stripped from ..\MIDS-W207-Spring24-Soccer-Detection\analysis\YOLOv5\train\exp\weights\last.pt, 3.9MB
# Optimizer stripped from ..\MIDS-W207-Spring24-Soccer-Detection\analysis\YOLOv5\train\exp\weights\best.pt, 3.9MB
#
# Validating ..\MIDS-W207-Spring24-Soccer-Detection\analysis\YOLOv5\train\exp\weights\best.pt...
# Fusing layers...
# Model summary: 157 layers, 1763224 parameters, 0 gradients, 4.1 GFLOPs
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:01<00:00,  1.08s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:01<00:00,  1.08s/it]
#                    all         15        345          0          0          0          0
# Results saved to ..\MIDS-W207-Spring24-Soccer-Detection\analysis\YOLOv5\train\exp
